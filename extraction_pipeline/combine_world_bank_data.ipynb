# %%
import pandas as pd
import os
import pickle
from fuzzywuzzy import fuzz
import matplotlib.pyplot as plt
import numpy as np

# %%
world_bank_projects = pd.read_pickle('../world_bank_projects/world_bank_projects_json.pkl')
loan_features = pd.read_pickle('agreement_features.pickle')

# %%
wb_project_names = world_bank_projects['project_name']
doc_project_names = loan_features['Project Name']

# %% [markdown]
# We will use fuzzy string matching to pair project names between the two tables. Let's explore a couple of algorithms. The first one compares substrings.

# %%
similarities = np.zeros((len(wb_project_names),len(doc_project_names)))
for i in range(len(wb_project_names)):
    if i % 100 == 0:
        print('computing similarities for world bank project name', i)
    for j in range(len(doc_project_names)):
        similarities[i,j] = fuzz.partial_ratio(wb_project_names.iloc[i],doc_project_names.iloc[j])
# Out:
# computing similarities for world bank project name 0
# computing similarities for world bank project name 100
# computing similarities for world bank project name 200
# computing similarities for world bank project name 300
# computing similarities for world bank project name 400
# computing similarities for world bank project name 500
# computing similarities for world bank project name 600
# computing similarities for world bank project name 700
# computing similarities for world bank project name 800
# computing similarities for world bank project name 900
# computing similarities for world bank project name 1000
# computing similarities for world bank project name 1100
# computing similarities for world bank project name 1200
# computing similarities for world bank project name 1300
# computing similarities for world bank project name 1400
# computing similarities for world bank project name 1500
# computing similarities for world bank project name 1600
# computing similarities for world bank project name 1700
# computing similarities for world bank project name 1800
# computing similarities for world bank project name 1900
# computing similarities for world bank project name 2000
# computing similarities for world bank project name 2100
# computing similarities for world bank project name 2200
# computing similarities for world bank project name 2300
# computing similarities for world bank project name 2400
# computing similarities for world bank project name 2500
# computing similarities for world bank project name 2600
# computing similarities for world bank project name 2700
# computing similarities for world bank project name 2800
# computing similarities for world bank project name 2900
# computing similarities for world bank project name 3000
# computing similarities for world bank project name 3100
# computing similarities for world bank project name 3200
# computing similarities for world bank project name 3300
# computing similarities for world bank project name 3400
# computing similarities for world bank project name 3500
# computing similarities for world bank project name 3600

# %% [markdown]
# Let's take a look at what the matches end up being.

# %%
matches = similarities.argmax(axis=0)
count = 0
for i in range(len(doc_project_names)):
    sim = similarities[matches[i],i]
    if sim > 95:
        count += 1
        print("doc project:\t", doc_project_names.iloc[i])
        print("best match:\t",wb_project_names.iloc[matches[i]])
        print("score:\t", sim)
# Out:
# nterprises Project
# score:	 100.0
# doc project:	 Water Supply Project
# best match:	 Additional Financing for the Greater Beirut Water Supply Project
# score:	 100.0
# doc project:	 Second Pollution Abatement Project
# best match:	 Second Pollution Abatement Project
# score:	 100.0
# doc project:	 Second State Statistical System Development Project
# best match:	 Second State Statistical System Development Project
# score:	 100.0
# doc project:	 Structural Adjustment Loan
# best match:	 CO: Programmatic Labor Reform and Social Structural Adjustment Loan
# score:	 100.0
# doc project:	 Transport Project
# best match:	 Meghalaya Integrated Transport Project
# score:	 100.0
# doc project:	 Financial Sector Adjustment Loan
# best match:	 Programmatic Financial Sector Adjustment Loan I
# score:	 100.0
# doc project:	 Programmatic Public Sector Development Policy Loan
# best match:	 Development Policy Loan
# score:	 100.0
# doc project:	 Absheron Rehabilitation Program II:
# Integrated Solid Waste Management Project
# best match:	 Integrated Solid Waste Management Project
# score:	 100.0
# doc project:	 Social Protection Project
# best match:	 Beneficiary FIRST Social Protection Project
# score:	 100.0
# doc project:	 National Railway Project
# best match:	 Third National Railway Project
# score:	 100.0
# doc project:	 Ain Temouchent Emergency Earthquake Recovery Project
# best match:	 Ain Temouchent Emergency Earthquake Recovery Project
# score:	 100.0
# doc project:	 Treasury Systems Project
# best match:	 Treasury Systems Project
# score:	 100.0
# doc project:	 Power Rehabilitation Project
# best match:	 Rehabilitation Project
# score:	 100.0
# doc project:	 Mato Grosso Fiscal Adjustment and Environmental Sustainability
#
# Development Policy Loan -
#
# Empréstimo de Politica de Desenvolvimento com Sustentabilidade Fiscal e Ambiental no Estado de
#
# Mato Grosso
# best match:	 Development Policy Loan
# score:	 100.0
# doc project:	 Hubei Jingzhou Historic Town Conservation Project
# best match:	 Hubei Jingzhou Historic Town Conservation Project
# score:	 100.0
# doc project:	 Institutions Building Technical Assistance Project
# best match:	 Technical Assistance Project
# score:	 100.0
# doc project:	 Land Administration and Management Project
# best match:	 Land Administration and Management Project
# score:	 100.0
# doc project:	 Solid Waste Management Project
# best match:	 Kerala Solid Waste Management Project
# score:	 100.0
# doc project:	 Education Improvement Project
# best match:	 Primary Education Improvement Project
# score:	 100.0
# doc project:	 First Development Policy Loan
# best match:	 First Development Policy Loan
# score:	 100.0
# doc project:	 Piaui Pillars of Growth and Social Inclusion Project -
#
# Piaui — Pilares de Crescimento e Inclusdo Social (SWAP
# best match:	 Social Inclusion Project
# score:	 100.0
# doc project:	 Northern Restructuring Project
# best match:	 Northern Restructuring Project
# score:	 100.0
# doc project:	 Republika Srpska Railways Restructuring Project
# best match:	 Republika Srpska Railways Restructuring Project
# score:	 100.0
# doc project:	 Structural Adjustment Loan
# best match:	 CO: Programmatic Labor Reform and Social Structural Adjustment Loan
# score:	 100.0
# doc project:	 Competitiveness Enhancement Technical A:sistance Project
# best match:	 Competitiveness Enhancement Technical Assistance Project
# score:	 98.0
# doc project:	 Gu izhou Rural Development Project
# best match:	 Rural Development Project
# score:	 100.0
# doc project:	 Farmer Support Services Project
# best match:	 Farmer Support Services Project
# score:	 100.0
# doc project:	 Additional Loan for Rijeka Gateway Project
# best match:	 Rijeka Gateway Project
# score:	 100.0
# doc project:	 Power Transmission Project
# best match:	 Second Power Transmission Project
# score:	 100.0
# doc project:	 Wholesale Markets Project I
# best match:	 Wholesale Markets Project
# score:	 100.0
# doc project:	 Second Oil Rehabilitation Project
# best match:	 Rehabilitation Project
# score:	 100.0
# doc project:	 Second Structural Adjustment Loan
# best match:	 Second Structural Adjustment Loan
# score:	 100.0
# doc project:	 Xiaolangdi Multipurpose Project
# best match:	 Xiaolangdi Multipurpose Project: Stage II
# score:	 100.0
# doc project:	 Second Rehabilitation Loan
# best match:	 Rehabilitation Loan
# score:	 100.0
# doc project:	 Public Expenditure and Fiscal Risk Management Development Policy Loan
# best match:	 Fiscal Risk Management Development Policy Loan
# score:	 100.0
# doc project:	 Zhuzhou Brownfield Remediation Project
# best match:	 Zhuzhou Brownfield Remediation Project
# score:	 100.0
# doc project:	 Industrial Pollution Control Project
# best match:	 Industrial Pollution Control Project
# score:	 100.0
# doc project:	 Ceará Integrated Water Resources Management Project - PROGERIRH
# best match:	 Water Resources Management Project
# score:	 100.0
# doc project:	 Third Municipal Development Project
# best match:	 Municipal Development
# score:	 100.0
# doc project:	 Marmara Earthquake Emergency Reconstruction Project
# best match:	 Marmara Earthquake Emergency Reconstruction Project
# score:	 100.0
# doc project:	 Klaipeda Port Project
# best match:	 Klaipeda Port Project
# score:	 100.0
# doc project:	 Universalization of Basic Education Project
# best match:	 Basic Education Project
# score:	 100.0
# doc project:	 Inner Mongolia Highway Project
# best match:	 Inner Mongolia Highway Project
# score:	 100.0
# doc project:	 Strengthening Public Sector Management
# Technical Assistance Project -
#
# Projeto de PromoVdo da Excel,ncia na Gestdo Piblica do Munic1pio do Rio de Janeiro
# - Projeto Rio de Excelncia
# best match:	 Technical Assistance Project
# score:	 100.0
# doc project:	 Integrated Irrigation Modernization Project
# best match:	 Integrated Irrigation Modernization Project
# score:	 100.0
# doc project:	 Fujian Provincial Highway Project
# best match:	 Highway Project
# score:	 100.0
# doc project:	 First Equitable Growth and Job Creation Development Policy Loan
# best match:	 Development Policy Loan
# score:	 100.0
# doc project:	 North Eastern Region Power System Improvement Project
# best match:	 North Eastern Region Power System Improvement Project
# score:	 100.0
# doc project:	 Ghazi-Barotha Hydropower Project
# best match:	 Ghazi Barotha Hydropower Project
# score:	 97.0
# doc project:	 Land Administration System Modernization Project
# best match:	 Land Administration System Modernization
# score:	 100.0
# doc project:	 Land-Based Poverty Alleviation Project I
# best match:	 Land-Based Poverty Alleviation Project I
# score:	 100.0
# doc project:	 Innovation for Competitiveness Project
# best match:	 Competitiveness Project
# score:	 100.0
# doc project:	 Energy Efficiency Financing Project
# best match:	 Energy Efficiency
# score:	 100.0
# doc project:	 Istanbul Municipal Infrastructure Project
# best match:	 Istanbul Municipal Infrastructure Project
# score:	 100.0
# doc project:	 Forests and Climate Change Project
# best match:	 Mexico Forests and Climate Change Project
# score:	 100.0
# doc project:	 First Municipal Finance Project - Kingdom
# best match:	 Municipal Finance Project
# score:	 100.0
# doc project:	 Power Transmission and Rehabilitation Project
# best match:	 Rehabilitation Project
# score:	 100.0
# doc project:	 Public Sector Adjustment Loan
# best match:	 Programmatic Financial & Public Sector Adjustment Loan 3 (PFPSAL 3)
# score:	 100.0
# doc project:	 Second Programmatic Energy and Water Sector Reforms Development Policy
# Loan
# best match:	 Second Programmatic Energy and Water Sector Reforms DPL
# score:	 96.0
# doc project:	 Basic Education Reform Project
# best match:	 Education Reform Project
# score:	 100.0
# doc project:	 Agricultural Development Project - Tamil Nadu
# best match:	 Agricultural Development Project
# score:	 100.0
# doc project:	 Highway Rehabilitation and Maintenance Project
# best match:	 National Highways Rehabilitation and Maintenance Project
# score:	 98.0
# doc project:	 Basic Education Project
# best match:	 Basic Education Project
# score:	 100.0
# doc project:	 First Social Development Project -- Education and Training
# best match:	 Social Development Project
# score:	 100.0
# doc project:	 Hubei Yiba Highway Project
# best match:	 Hubei Yiba Highway
# score:	 100.0
# doc project:	 Gas System Expansion Project
# best match:	 Gas System Expansion Project
# score:	 100.0
# doc project:	 Telecommunications Project
# best match:	 Jordan Telecommunications Project
# score:	 100.0
# doc project:	 Second Education Development Policy Loan
# best match:	 Second Education Development Policy Loan
# score:	 100.0
# doc project:	 Bicol Power Restoration Project
# best match:	 Bicol Power Restoration Project
# score:	 100.0
# doc project:	 Competitiveness and Employment Development Policy Loan
# best match:	 Development Policy Loan
# score:	 100.0
# doc project:	 Housing Finance and Urban Sector Reform Project
# best match:	 Housing Finance and Urban Sector Reform Project
# score:	 100.0
# doc project:	 Sustaining Reforms for Inclusive Growth Development Policy Loan
# best match:	 Sustaining Reforms for Inclusive Growth
# score:	 100.0
# doc project:	 Third Integrated Financial Management Technical Assistance Project
# best match:	 Technical Assistance Project
# score:	 100.0
# doc project:	 Integrated Disaster Risk Management and Resilience Program
# best match:	 Integrated Disaster Risk Management and Resilience Program
# score:	 100.0
# doc project:	 Jiangsu Provincial Transport Project
# best match:	 Transport Project
# score:	 100.0
# doc project:	 Housing Project
# best match:	 Improving Access to Affordable Housing Project
# score:	 100.0
# doc project:	 Liepaja Region Solid Waste Management Project
# best match:	 Liepaja Region Solid Waste Management Project
# score:	 100.0
# doc project:	 Housing Project
# best match:	 Improving Access to Affordable Housing Project
# score:	 100.0
# doc project:	 Social Investment Fund Project
# best match:	 Social Investment Fund Project
# score:	 100.0
# doc project:	 Rural Finance Project
# best match:	 Expanding Rural Finance Project
# score:	 100.0
# doc project:	 Social Protection Adjustment Loan
# best match:	 Social Protection Adjustment Loan
# score:	 100.0
# doc project:	 Program Towards Elimination of Tuberculosis
# best match:	 Program Towards Elimination of Tuberculosis
# score:	 100.0
# doc project:	 Pre-Export Guarantee Facility Project
# best match:	 Pre-Export Guarantee Facility
# score:	 100.0
# doc project:	 Urban Development Project
# best match:	 National Urban Development Project (NUDP)
# score:	 100.0
# doc project:	 Roads and Safety Improvement Project
# best match:	 Roads and Safety Improvement
# score:	 100.0
# doc project:	 Second Sustainability and Competitiveness Development Policy Loan
# best match:	 Development Policy Loan
# score:	 100.0
# doc project:	 Urban Development and Poor Neighborhood Upgrading Project
# best match:	 Urban Development and Poor Neighborhood Upgrading Project
# score:	 100.0
# doc project:	 Strengthening Entrepreneurship in Productive Forest Landscapes Project
# best match:	 Strengthening Entrepreneurship in Productive Forest Landscapes
# score:	 100.0
# doc project:	 Quality of Undergraduate Education Project
# best match:	 Quality of Undergraduate Education
# score:	 100.0
# doc project:	 Second National Highway Project
# best match:	 Highway Project
# score:	 100.0
# doc project:	 Institutional Development and Agriculture Strengthening Project
# best match:	 Montenegro Second Institutional Development and Agriculture Strengthening Project
# score:	 100.0
# doc project:	 Small and Medium Enterprises Energy Efficiency Project
# best match:	 Energy Efficiency
# score:	 100.0
# doc project:	 First Broad-Based Growth Development Policy Loan
# best match:	 Development Policy Loan
# score:	 100.0
# doc project:	 2nd Additional Financing for Energy Efficiency Facility for
# Industrial Enterprises Project
# best match:	 Energy Efficiency
# score:	 100.0
# doc project:	 Third Highway Project
# best match:	 Third Highway Project
# score:	 100.0
# doc project:	 Environment and Natural Resources Sector Adjustment
# best match:	 Environment and Natural Resources Sector Adjustment Project
# score:	 100.0
# doc project:	 Third South West Indian Ocean Fisheries Governance and Shared Growth Project
# best match:	 Third South West Indian Ocean Fisheries Governance and Shared Growth Project (SWIOFish3)
# score:	 100.0
# doc project:	 First Programmal ic Shared Prosperity Development Policy Loan
# best match:	 Development Policy Loan
# score:	 100.0
# doc project:	 Pilot Community Infrastructure Works and Capacity Building Project
# best match:	 Pilot Community Infrastructure Works and Capacity Building Project
# score:	 100.0
# doc project:	 Northern Border Environment Project
# best match:	 Environment Project
# score:	 100.0
# doc project:	 Natural. Resources Management Project
# best match:	 Tunisia Second Natural Resources Management Project
# score:	 99.0
# doc project:	 National Transmission Grid Project
# best match:	 National Transmission Grid Project
# score:	 100.0
# doc project:	 Education Quality Improvement Project
# best match:	 Education Quality Improvement Project
# score:	 100.0
# doc project:	 Power System Development Project-III
# best match:	 Power System Development Project
# score:	 100.0
# doc project:	 Public Investment Strengthening Technical Assistance Project
# best match:	 Public Investment Strengthening Technical Assistance Project
# score:	 100.0
# doc project:	 Yunnan Environment Project
# best match:	 Environment Project
# score:	 100.0
# doc project:	 Municipal Sector Investment Project
# best match:	 Municipal Sector Investment Project
# score:	 100.0
# doc project:	 Industrial Pollution Prevention Project
# best match:	 Industrial Pollution Prevention Project
# score:	 100.0
# doc project:	 Sustainable Development Investment Project
# best match:	 Colombia Sustainable Development Investment Project - Additional Financing
# score:	 100.0
# doc project:	 Mining Development Technical Assistance Project
# best match:	 Second Mining Development Technical Assistance Project
# score:	 100.0
# doc project:	 Community Forestry Project
# best match:	 Community Forestry Project
# score:	 100.0
# doc project:	 Tehran Sewerage Project
# best match:	 Tehran Sewerage project
# score:	 96.0
# doc project:	 Second Agriculture Sector Investment Project
# best match:	 Agricultural Sector Investment Project
# score:	 96.0
# doc project:	 Third National Railway Project
# best match:	 Third National Railway Project
# score:	 100.0
# doc project:	 Environmental Research and Education Project
# best match:	 Environmental Research and Education Project
# score:	 100.0
# doc project:	 Shanghai Environment Project
# best match:	 Environment Project
# score:	 100.0
# doc project:	 Liaoning Third Medium Cities Infrastructure Project
# best match:	 Liaoning Third Medium Cities Infrastructure
# score:	 100.0
# doc project:	 Privatization Technical Assistance Project
# best match:	 Privatization Technical Assistance Project
# score:	 100.0
# doc project:	 Second Financial Sector Development Policy Loan
# best match:	 Development Policy Loan
# score:	 100.0
# doc project:	 Rijeka Gateway Project
# best match:	 Rijeka Gateway Project
# score:	 100.0
# doc project:	 Shandong Environment Project
# best match:	 Environment Project
# score:	 100.0
# doc project:	 Economic and Social Development Policy Loan
# best match:	 Development Policy Loan
# score:	 100.0
# doc project:	 Modernization and Innovation for Better Public Services in Argentina Project
# best match:	 Modernization and Innovation for Better Public Services in Argentina
# score:	 100.0
# doc project:	 Secondary School Teacher Development Project
# best match:	 Secondary School Teacher Development Project
# score:	 100.0
# doc project:	 Financial Sector Development Project
# best match:	 Financial Sector Development Project
# score:	 100.0
# doc project:	 Health Sector Technology Transfer and Institutional Reform Project
# best match:	 Health Sector Technology Transfer and Institutional Reform
# score:	 100.0
# doc project:	 Second Municipal Services Improvement Project
# best match:	 Municipal Services Improvement Project
# score:	 100.0
# doc project:	 Municipal Water Project
# best match:	 Municipal Water Project
# score:	 100.0
# doc project:	 Second Eastern Indonesia Region Transport Project
# best match:	 Second Eastern Indonesia Region Transport Project
# score:	 100.0
# doc project:	 Programmatic Adjustment Loan
# best match:	 Croatia Programmatic Adjustment Loan 2 (PAL2)
# score:	 100.0
# doc project:	 Treasury Development Project
# best match:	 Treasury Development Project
# score:	 100.0
# doc project:	 Additional Financing for the Yunnan Urban Environment Project
# best match:	 Yunnan Urban Environment Project
# score:	 100.0
# doc project:	 District Heating Project
# best match:	 Belarus Biomass District Heating Project
# score:	 100.0
# doc project:	 Agrarian Reform Communities Development Project
# best match:	 PH - Additional Financing for the Second Agrarian Reform Communities Development Project
# score:	 100.0
# doc project:	 Technician Education Project
# best match:	 Technician Education Project
# score:	 100.0
# doc project:	 Second Municipal Development Project
# best match:	 Municipal Development
# score:	 100.0
# doc project:	 Housing Project
# best match:	 Improving Access to Affordable Housing Project
# score:	 100.0
# doc project:	 Punjab State Road Sector Project
# best match:	 Punjab State Road Sector Project
# score:	 100.0
# doc project:	 Rehabilitation Loan
# best match:	 Critical Imports Rehabilitation Loan
# score:	 100.0
# doc project:	 Private Investment Credit Project
# best match:	 Tunisia Private Investment Credit Project
# score:	 100.0
# doc project:	 Technical Education and Training Modernization Project
# best match:	 Technical Education and Training Modernization Project
# score:	 100.0
# doc project:	 CAT-DDO
# best match:	 Second Disaster Risk Management Development Policy Loan with a CAT-DDO
# score:	 100.0
# doc project:	 Fostering Productive Innovation Project
# best match:	 Kazakhstan: Fostering Productive Innovation Project
# score:	 100.0
# doc project:	 Financial and Corporate Restructuring Assistance Project
# best match:	 Financial and Corporate Restructuring Assistance Project
# score:	 100.0
# doc project:	 Liuzhou Environment Management Project
# best match:	 Liuzhou Environment Management Project Phase II
# score:	 100.0
# doc project:	 BEPEKA Audit Modernization Project
# best match:	 BEPEKA Audit Modernization Project
# score:	 100.0
# doc project:	 Sergipe State Integrated Project: Rural Poverty – Projeto de Combate a Pobreza Rural no
# Estado do Sergipe “PCPR II – 2a Fase”
# best match:	 Sergipe State Integrated Project: Rural Poverty
# score:	 100.0
# doc project:	 Additional Financing for the Second Export Development Project
# best match:	 Export Development Project
# score:	 100.0
# doc project:	 First Programmatic Public Sector, Competitiveness
#
# and Social Inclusion Development Policy Loan
# best match:	 Development Policy Loan
# score:	 100.0
# doc project:	 Electricity Distribution Rehabilitation Project
# best match:	 DO Electricity Distribution Rehabilitation Project
# score:	 100.0
# doc project:	 Pernambuco Equity and Inclusive Growth Development Policy Loan
# Programa de Desenvolvimento das Politicas Piblicas do Estado
#
# de Pernambuco II - DPL
# best match:	 Development Policy Loan
# score:	 100.0
# doc project:	 Second Programmatic Public Sector, Competitiveness and Social Inclusion
#
# Development Policy Loan
# best match:	 Development Policy Loan
# score:	 100.0
# doc project:	 Tertiary Education Finance for Results Project
# best match:	 Tertiary Education Finance for Results Project III
# score:	 100.0
# doc project:	 Water Supply and Sewerage Project
# best match:	 Water Supply and Sewerage Project (02)
# score:	 100.0
# doc project:	 Berke Hydropower Project
# best match:	 Berke Hydropower Project
# score:	 100.0
# doc project:	 Secondary Education Support Project
# best match:	 Secondary Education Support Project
# score:	 100.0
# doc project:	 Technical Assistance Project
# best match:	 Public Finance Management Technical Assistance Project
# score:	 100.0
# doc project:	 Tertiary Education Finance for Results Project III
# best match:	 Tertiary Education Finance for Results Project III
# score:	 100.0
# doc project:	 Chimborazo Development Investment Project (PIDD
# best match:	 EC Chimborazo Development Investment Project (PIDD)
# score:	 100.0
# doc project:	 Third Upper Secondary Education
# Development Policy Loan
# best match:	 Development Policy Loan
# score:	 100.0

# %% [markdown]
# Hmm, the substring matching means that some generic project names get matched to something more specific.

# %%
count
# Out:
# 2388

# %% [markdown]
# This is a stricter version, which runs faster and just computes the Levenshtein distance between two strings, dividing by the length.

# %%
strict_similarities = np.zeros((len(wb_project_names),len(doc_project_names)))
for i in range(len(wb_project_names)):
    if i % 100 == 0:
        print('computing similarities for world bank project name', i)
    for j in range(len(doc_project_names)):
        strict_similarities[i,j] = fuzz.ratio(wb_project_names.iloc[i],doc_project_names.iloc[j])
# Out:
# computing similarities for world bank project name 0
# computing similarities for world bank project name 100
# computing similarities for world bank project name 200
# computing similarities for world bank project name 300
# computing similarities for world bank project name 400
# computing similarities for world bank project name 500
# computing similarities for world bank project name 600
# computing similarities for world bank project name 700
# computing similarities for world bank project name 800
# computing similarities for world bank project name 900
# computing similarities for world bank project name 1000
# computing similarities for world bank project name 1100
# computing similarities for world bank project name 1200
# computing similarities for world bank project name 1300
# computing similarities for world bank project name 1400
# computing similarities for world bank project name 1500
# computing similarities for world bank project name 1600
# computing similarities for world bank project name 1700
# computing similarities for world bank project name 1800
# computing similarities for world bank project name 1900
# computing similarities for world bank project name 2000
# computing similarities for world bank project name 2100
# computing similarities for world bank project name 2200
# computing similarities for world bank project name 2300
# computing similarities for world bank project name 2400
# computing similarities for world bank project name 2500
# computing similarities for world bank project name 2600
# computing similarities for world bank project name 2700
# computing similarities for world bank project name 2800
# computing similarities for world bank project name 2900
# computing similarities for world bank project name 3000
# computing similarities for world bank project name 3100
# computing similarities for world bank project name 3200
# computing similarities for world bank project name 3300
# computing similarities for world bank project name 3400
# computing similarities for world bank project name 3500
# computing similarities for world bank project name 3600

# %%
matches = strict_similarities.argmax(axis=0)
count = 0
for i in range(len(doc_project_names)):
    sim = strict_similarities[matches[i],i]
    if sim > 90:
        count += 1
        if sim < 100:
            print("doc project:\t", doc_project_names.iloc[i])
            print("best match:\t",wb_project_names.iloc[matches[i]])
            print("score:\t", sim)
# Out:
# nnection Project
# score:	 93.0
# doc project:	 Disaster Risk Management Development Policy Loan
# With a Catastrophe Deferred Drawdown Option
# best match:	 Disaster Risk Management Development Policy Loan with a Catastrophe Deferred Drawdown Option
# score:	 98.0
# doc project:	 Cebu Bus Rapid Transit Project
# best match:	 Cebu Bus Rapid Transit (BRT) Project
# score:	 91.0
# doc project:	 Third Development Policy Loan to Foster More Inclusive Growth
# best match:	 Philippines Development Policy Loan to Foster More Inclusive Growth
# score:	 91.0
# doc project:	 Cebu Bus Rapid Transit Project
# best match:	 Cebu Bus Rapid Transit (BRT) Project
# score:	 91.0
# doc project:	 National and Regional Roads Rehabilitation Project
# best match:	 National and Regional Roads Rehabilitation
# score:	 91.0
# doc project:	 Gu izhou Rural Development Project
# best match:	 Guizhou Rural Development Project
# score:	 99.0
# doc project:	 Transmission Efficiency Project
# best match:	 Transmission Efficiency Project (TEP)
# score:	 91.0
# doc project:	 Qinghai Xining Water Environment Management Project
# best match:	 China-Qinghai Xining Water Environment Management Project
# score:	 94.0
# doc project:	 Second Programmatic Productive and Sustainable Cities
#
# Development Policy Loan
# best match:	 Second Programmatic Productive & Sustainable Cities Development Policy Loan
# score:	 96.0
# doc project:	 Gansu Rural-Urban Integration Project
# best match:	 China: Gansu Rural-Urban Integration Project
# score:	 91.0
# doc project:	 Tamil Nadu Sustainable Urban Development Project
# best match:	 Tamil Nadu Sustainable Urban Development Program
# score:	 92.0
# doc project:	 Guayaquil Wastewater Management Project
# best match:	 Guayaquil Wastewater Management Project AF
# score:	 96.0
# doc project:	 Innovation atd Entrepreneurship Venture Capital Project
# best match:	 Croatia Innovation and Entrepreneurship Venture Capital Project
# score:	 92.0
# doc project:	 Second Resilience and Growth Development Policy Loan
# best match:	 Resiliance and Growth Development Policy Loan
# score:	 91.0
# doc project:	 Poverty Alleviation and Agriculture-Based Industry Pilot and Demonstration in Poor
# Areas Project
# best match:	 Poverty Alleviation and Agriculture-based Industry Pilot and Demonstration in Poor Areas Project
# score:	 98.0
# doc project:	 Reducing Inequality of Educational Opportunity Project
# best match:	 Mexico Reducing Inequality of Educational Opportunity Project
# score:	 94.0
# doc project:	 Second Programmatic Financial Sector Development Policy Loan
# best match:	 Programmatic Financial Sector Development Policy Loan
# score:	 94.0
# doc project:	 Road Transport Corridors Project
# best match:	 Transport Corridors Project
# score:	 92.0
# doc project:	 Sustainable Rural Sanitation Services Program
# best match:	 AF to Sustainable Rural Sanitation Services Program
# score:	 94.0
# doc project:	 Large Scale Irrigation Modernization Project
# best match:	 MA-Large Scale Irrigation Modernization Project
# score:	 97.0
# doc project:	 Second Programmatic Resilience Building Development Policy Loan
# best match:	 Second Programmatic Resilience Building Development Policy Credit
# score:	 92.0
# doc project:	 Tianjin Urban Transport Improvement Project
# best match:	 China: Tianjin Urban Transport Improvement Project
# score:	 92.0
# doc project:	 Tertiary Education for Employability Project
# best match:	 Tunisia Tertiary Education for Employability Project
# score:	 92.0
# doc project:	 Road Sector Capacity Development Project
# best match:	 BO Road Sector Capacity Development Project
# score:	 96.0
# doc project:	 Swachh Bharat Mission Support Operation
# best match:	 IN Swachh Bharat Mission Support Operation
# score:	 96.0
# doc project:	 First Programmatic Electricity Distribution Reform Development Policy Loan for
# Rajasthan
# best match:	 First Programmatic Electricity Distribution Reform Development Policy Loan for Rajasthan
# score:	 99.0
# doc project:	 Skills Development and Employability Project
# best match:	 Gabon - Skills Development and Employability Project
# score:	 92.0
# doc project:	 Transport Infrastructure Investment Project
# best match:	 Fiji Transport Infrastructure Investment Project
# score:	 95.0
# doc project:	 Strengthening Universal Health Insurance in Costa Rica Program
# best match:	 Strengthening Universal Health Insurance in Costa Rica
# score:	 93.0
# doc project:	 Risk Mitigation and Emergency Recovery Project
# best match:	 Ecuador Risk Mitigation and Emergency Recovery Project
# score:	 92.0
# doc project:	 Karnataka Urban Water Supply Modernization Project
# best match:	 IN Karnataka Urban Water Supply Modernization Project
# score:	 97.0
# doc project:	 Additional Financing for IDP Living Standards and Livelihood Project
# best match:	 Additional Financing to IDP Living Standards and Livelihoods Project
# score:	 97.0
# doc project:	 Can Tho Urban Development and Resilience Project
# best match:	 Can Tho Urban Development and Resilience
# score:	 91.0
# doc project:	 Post-Cyclone Winston Emergency Development Policy Operation
# best match:	 Fiji Post-Cyclone Winston Emergency Development Policy Operation
# score:	 96.0
# doc project:	 Third Economic Management and Competitiveness Development Policy Operation
# best match:	 Economic Management and Competitiveness Development Policy Operation
# score:	 96.0
# doc project:	 Upper Egypt Local Development Program
# best match:	 Upper Egypt Local Development PforR
# score:	 92.0
# doc project:	 Second Programmatic Shared Prosperity Development Policy Financing
# best match:	 Third Programmatic Shared Prosperity Development Policy Financing
# score:	 93.0
# doc project:	 Project for Integrated Urban and Tourism Development
# best match:	 Project for Integrated Urban and Tourism Development (PIUTD)
# score:	 93.0
# doc project:	 Sustainable Cities Project
# best match:	 Sustainable Cities Project 2
# score:	 96.0
# doc project:	 Hunan Fiscal Sustainability Development Policy Loan
# best match:	 Iraq Fiscal Sustainability Development Policy Loan
# score:	 93.0
# doc project:	 Strengthening the Science, Technology and Innovation System Project
# best match:	 Strengthening the Science, Technology and Innovation System in Peru
# score:	 93.0
# doc project:	 Competitiveness Development Policy Loan
# best match:	 Albania Competitiveness Development Policy Loan
# score:	 91.0
# doc project:	 Yunnan Early Childhood Education Innovation Project
# best match:	 Yunnan Early Childhood Education Innovation Project (YECEIP)
# score:	 92.0
# doc project:	 National Program for Innovation in Fisheries and Aquaculture Project
# best match:	 National Program for Innovation in Fisheries and Aquaculture
# score:	 94.0
# doc project:	 National Program for Innovation in Fisheries and Aquaculture Project
# best match:	 National Program for Innovation in Fisheries and Aquaculture
# score:	 94.0
# doc project:	 Improving the Quality of Initial and Primary Education in Uruguay Project
# best match:	 Improving the Quality of Initial and Primary Education in Uruguay
# score:	 94.0
# doc project:	 Statistical Development Project
# best match:	 Gabon Statistical Development Project
# score:	 91.0
# doc project:	 Second Programmatic Inclusive Growth Development Policy Operation
# best match:	 First Programmatic Inclusive Growth Development Policy Operation
# score:	 91.0
# doc project:	 Modernization and Restructuring of the Road Sector Project
# best match:	 Modernization and Restructuring of the Road Sector
# score:	 93.0
# doc project:	 Inclusive Early Childhood Education and Care Project
# best match:	 Inclusive Early Childhood Education and Care
# score:	 92.0
# doc project:	 Disaster Risk Management Development Policy Loan
# with a Catastrophe-Deferred Drawdown Option
# best match:	 Disaster Risk Management Development Policy Loan with a Catastrophe Deferred Drawdown Option
# score:	 98.0
# doc project:	 Regional Infrastructure Development Fund Project
# best match:	 Regional Infrastructure Development Fund
# score:	 91.0
# doc project:	 Identity and Targeting for Social Protection Project
# best match:	  Identity and Targeting for Social Protection Project
# score:	 99.0
# doc project:	 Coral Reef Rehabilitation and Management Program - Coral Triangle Initiative
# (COREMAP-CTI
# best match:	 Coral Reel Rehabilitation and Management Program -Coral Triangle Initiative (COREMAP-CTI)
# score:	 97.0
# doc project:	 Gansu Technical and Vocational Education and Training Project
# best match:	 China: Gansu Technical and Vocational Education and Training Project
# score:	 95.0
# doc project:	 Assam State Public Finance Institutional Reforms (ASPIRe
# best match:	 Assam State Public Finance Institutional Reforms (ASPIRe) Project
# score:	 93.0
# doc project:	 Second Gansu Cultural and Natural Heritage Protection and Development Project
# best match:	 CH-Second Gansu Cultural and Natural Heritage Protection and Development Project
# score:	 98.0
# doc project:	 Additional Financing for Rural Alliances Project II
# best match:	 Additional Finance BO Rural Alliances Project II
# score:	 91.0
# doc project:	 Access and Quality in Higher Education Project
# best match:	 Access and Quality in Higher Education Project - PACES
# score:	 92.0
# doc project:	 Inclusive Partnerships for Agricultural Competitiveness Project
# best match:	 Inclusive Partnerships for Agricultural Competitiveness
# score:	 93.0
# doc project:	 Modernization and Innovation for Better Public Services in Argentina Project
# best match:	 Modernization and Innovation for Better Public Services in Argentina
# score:	 94.0
# doc project:	 Modernization and Upgrade of Transmission Substations Project
# best match:	 Modernization and Upgrade of Transmission Substations
# score:	 93.0
# doc project:	 Third South West Indian Ocean Fisheries Governance and Shared Growth Project
# best match:	 Third South West Indian Ocean Fisheries Governance and Shared Growth Project (SWIOFish3)
# score:	 93.0
# doc project:	 Third South West Indian Ocean Fisheries Governance and Shared Growth Project
# best match:	 Third South West Indian Ocean Fisheries Governance and Shared Growth Project (SWIOFish3)
# score:	 93.0
# doc project:	 Enhancing Infrastructure Efficiency and Sustainability Program
# best match:	 Enhancing Infrastructure Efficiency and Sustainability
# score:	 93.0
# doc project:	 Improving Service Delivery to Citizens and Businesses through E-Government Project
# best match:	 Uruguay - Improving Service Delivery to Citizens and Businesses through E-Government Project
# score:	 94.0
# doc project:	 Odisha Higher Education Program for Exceglence and Equity
# best match:	 Odisha Higher Education Program for Excellence and Equity
# score:	 98.0
# doc project:	 Grain Storage and Information for Agricultural Competitiveness Project
# best match:	 Grain Storage and Information for Agricultural Competitiveness
# score:	 94.0
# doc project:	 Additional Financing for the Irrigation System Enhancement Project
# best match:	 Additional Financing Irrigation System Enhancement Project
# score:	 94.0
# doc project:	 Strengthening of State Universities in Chile Project
# best match:	 Strengthening of State Universities in Chile
# score:	 92.0
# doc project:	 Guangdong Compulsory Education Project
# best match:	 China: Guangdong Compulsory Education Project
# score:	 92.0
# doc project:	 Uftarakhand Water Supply Program for Pei-Urbam Areas
# best match:	 Uttarakhand Water Supply Program for Peri Urban Areas
# score:	 93.0
# doc project:	 Tamil Nadu Rural Transformation Project
# best match:	 Tamil Nadu Rural Transformation Project (TNRTP)
# score:	 91.0
# doc project:	 Access to Finance for Micro, Small and Medium Enterprises Project
# best match:	 Access to Longer Term Finance for Micro, Small and Medium Enterprises Project
# score:	 92.0
# doc project:	 Jiangxi Farm Produce Distribution System Development Project
# best match:	 Jiangxi Farm Produce Distribution System Development
# score:	 93.0
# doc project:	 Second Institutional Development and Agriculture Strengthening Project
# best match:	 Montenegro Second Institutional Development and Agriculture Strengthening Project
# score:	 93.0
# doc project:	 State-Owned Financial Institutions Strengthening Project
# best match:	 State Owned Financial Institutions Strengthening Project
# score:	 98.0
# doc project:	 Maharashtra Project on Climate Resilient Agriculture (PoCRA
# best match:	 Maharashtra Project on Climate Resilient Agriculture
# score:	 94.0
# doc project:	 Strengthening Entrepreneurship in Productive Forest Landscapes Project
# best match:	 Strengthening Entrepreneurship in Productive Forest Landscapes
# score:	 94.0
# doc project:	 Cashew Value-Chain Competitiveness Project
# best match:	 Cashew Value Chain Competitiveness Project
# score:	 98.0
# doc project:	 Madhya Pradesh Rural Connectivity Project
# best match:	 Madhya Pradesh Rural Connectivity project
# score:	 98.0
# doc project:	 Emergency Social Stabilization and Resilience Project
# best match:	 Iraq Emergency Social Stabilization and Resilience Project
# score:	 95.0
# doc project:	 Additional Financing for the Horticulture Development Project
# best match:	 Additional Financing - Horticulture Development Project
# score:	 93.0
# doc project:	 Strengthening Public Financial Management in Rajasthan Project
# best match:	 Strengthening Public Financial Management in Rajasthan
# score:	 93.0
# doc project:	 Additional Financing for the Social Assistance Modernization Project
# best match:	 Additional Financing  Social Assistance Modernization project
# score:	 93.0
# doc project:	 National Transmission Modernization - I Project
# best match:	 National Transmission Modernization I Project
# score:	 98.0
# doc project:	 Support for the National Indigenous Peoples Development Plan Project
# best match:	 Support for the National Indigenous Peoples Development Plan
# score:	 94.0
# doc project:	 Additional Financing for the Statistics Capacity Building Project
# best match:	 Additional Financing - RoC - Statistics Capacity Building Project
# score:	 92.0
# doc project:	 Support to Enterprise Development and Competitiveness Project
# best match:	 Support to Enterprise Development and Competitiveness  Project
# score:	 99.0
# doc project:	 Angola Health System Performance Strengthening Project
# best match:	 Angola Health System Performance Strengthening Project (HSPSP)
# score:	 93.0
# doc project:	 Disaster Risk Management Development Policy Loan
#
# with a Catastrophe-Deferred Drawdown Option
# best match:	 Disaster Risk Management Development Policy Loan with a Catastrophe Deferred Drawdown Option
# score:	 97.0
# doc project:	 Jiangxi Integrated Rural and Urban Water Supply and
# Wastewater Management Project
# best match:	  Jiangxi Integrated Rural and Urban Water Supply and Wastewater Management Project
# score:	 98.0
# doc project:	 Brazil-Salvador Social Multi-Sector Service Delivery Project
# best match:	 Salvador Social Multi-Sector Service Delivery Project
# score:	 94.0
# doc project:	 Hubei Inland Waterway Improvement Project
# best match:	 China: Hubei Inland Waterway Improvement Project
# score:	 92.0
# doc project:	 Commercial Agriculture Development Project
# best match:	 Angola: Commercial Agriculture Development Project
# score:	 91.0
# doc project:	 Liaoning Safe and Sustainable Urban Water Supply Project
# best match:	 China: Liaoning Safe and Sustainable Urban Water Supply Project
# score:	 94.0
# doc project:	 Zhejiang Qiandao Lake and Xin'an River Basin Water Resources and Ecological
# Environment Protection Project
# best match:	 Zhejiang Qiandao Lake and Xin'an River Basin Water Resources and Ecological Environment Protection Project
# score:	 99.0
# doc project:	 Additional Financing for the Energy Efficiency in Public Facilities Project -
# PRESEMEH
# best match:	 Additional Financing for Energy Efficiency in Public Facilities Project  (PRESEMEH)
# score:	 95.0
# doc project:	 Hezhou Urban Water Infrastructure and
# Environment Improvement Project
# best match:	 Hezhou Urban Water Infrastructure and Environment Improvement Project
# score:	 99.0
# doc project:	 Second Programmatic Electricity Distribution Reform Development Policy Loan for
# Rajasthan
# best match:	 First Programmatic Electricity Distribution Reform Development Policy Loan for Rajasthan
# score:	 93.0
# doc project:	 Additional Financing for the Access and Quality in Higher Education Project
# best match:	 Additional Financing for Access and Quality in Higher Education Project - PACES
# score:	 92.0
# doc project:	 Disaster Vulnerability Reduction Project
# best match:	 Disaster Vulnerability Reduction Project - APL2
# score:	 92.0
# doc project:	 Additional Financing for the Quito Metro Line One Project
# best match:	 Additional Financing Quito Metro Line One Project
# score:	 92.0
# doc project:	 Supporting Effective Universal Health Coverage in Argentina Project
# best match:	 Supporting Effective Universal Health Coverage in Argentina
# score:	 94.0
# doc project:	 Additional Financing for the Children and Youth Protection Project
# best match:	 Second Additional Financing for the Children and Youth Protection Project
# score:	 95.0
# doc project:	 Integrated Risk Management in the Rural Agroindustrial System Project
# best match:	 Integrated Risk Management in the Rural Agroindustrial System
# score:	 94.0
# doc project:	 National Rural Economic Transformation Project -
# Additional Financing for the National Rural Livelihoods Project
# best match:	 National Rural Economic Transformation Project ( Additional Financing to National Rural Livelihoods Project )
# score:	 94.0
# doc project:	 Framework Development and Infrastructure Financing to Support Public Private
#
# Partnerships Project
# best match:	 Framework Development and Infrastructure Financing to Support Public-Private Partnerships Project
# score:	 98.0
# doc project:	 Catalyzing Entrepreneurship for Job Creation Project
# best match:	 Catalyzing Entrepreneurship for Job Creation
# score:	 92.0
# doc project:	 Crecer Sano: Guatemala Nutrition and Health Project
# best match:	 Crecer Sano: Guatemala Nutrition and Health  Project
# score:	 99.0
# doc project:	 Land Administration System Modernization Project
# best match:	 Land Administration System Modernization
# score:	 91.0
# doc project:	 Paraguay Public Health Sector Strengthening Project
# best match:	 Paraguay Public Health Sector Strengthening
# score:	 91.0
# doc project:	 Energy Supply Reliability and Financial Recovery Project
# best match:	 Energy Supply Reliability and Financial Recovery
# score:	 92.0
# doc project:	 Energy Supply Reliability and Financial Recovery Project
# best match:	 Energy Supply Reliability and Financial Recovery
# score:	 92.0
# doc project:	 Rajasthan State Highways Development Program II Project
# best match:	 Rajasthan State Highways Development Program II
# score:	 92.0
# doc project:	 Strengthening the National Social Protection System Project (Cash Transfer
# best match:	 Strengthening the National Social Protection System Project (Cash Transfer)
# score:	 99.0
# doc project:	 Utility Efficiency and Quality Improvement Project
# best match:	 Belarus Utility Efficiency and Quality Improvement Project
# score:	 93.0
# doc project:	 Enhancing Waterway Connectivity and Water Service Provision in Colombia’s Plan
#
# Pazcifico Project
# best match:	 Enhancing Waterway Connectivity and Water Service Provision in Colombia&#8217;s Plan Pazcifico
# score:	 91.0
# doc project:	 Competitiveness and Sector Diversification Project
# best match:	 Competitiveness and Sector Diversification
# score:	 91.0
# doc project:	 Supporting the Electricity Social Tariff Transition in the Province of Buenos Aires Project
# best match:	 Supporting the Electricity Social Tariff Transition in the Province of Buenos Aires
# score:	 95.0
# doc project:	 National Urban Development Project
# best match:	 National Urban Development Project (NUDP)
# score:	 91.0
# doc project:	 Realizing Education's Promise: Support to Indonesia's Ministry of Religious Affairs for
# Improved Quality of Education Project
# best match:	 Realizing  Education's  Promise:  Support to Indonesia's Ministry of Religious Affairs for Improved Quality of Education
# score:	 95.0
# doc project:	 Affordable Housing Finance Project
# best match:	 Kenya Affordable Housing Finance Project
# score:	 92.0
# doc project:	 Additional Financing for the Support to the National Education Pact Project
# best match:	 Additional Financing - Support to the National Education Pact Project
# score:	 94.0

# %%
count
# Out:
# 1789

# %% [markdown]
# Let's use the strict matching, since we can be more confident that the projects will be correctly matched. Also, some project names are not unique, so we'll leave them out from both directions.

# %%
wb_value_counts = wb_project_names.value_counts()
doc_value_counts = doc_project_names.value_counts()
project_ids = []
def get_project_id(k):
    if strict_similarities[matches[k],k] > 90:
        project_name = doc_project_names.iloc[k]
        match_name = wb_project_names.iloc[matches[k]]
        if wb_value_counts[match_name] == 1 and doc_value_counts[project_name] == 1:
            return world_bank_projects.id.iloc[matches[k]]
        else:
            return None
    else:
        return None

loan_features['wb_project_id'] = list(map(get_project_id, range(len(loan_features))))

# %%
loan_features['wb_project_id'].describe()
# Out:
# count        1074
# unique       1006
# top       P166303
# freq            4
# Name: wb_project_id, dtype: object

# %% [markdown]
# It looks like there are still some pairs of loans that map to the same project, even with the strict matching and requiring that they be unique. But they should at least have the same type of project, so the resulting sector should be correct still.

# %%
loan_features['wb_project_id'].value_counts()
# Out:
# P166303    4
# P105002    3
# P115566    2
# P049537    2
# P068368    2
#           ..
# P159995    1
# P070441    1
# P150008    1
# P044832    1
# P096920    1
# Name: wb_project_id, Length: 1006, dtype: int64

# %%
loan_features.loc[loan_features['wb_project_id'] == 'P166303']
# Out:
#                       id        date country_code country_name  \
# 2622  431661468335398275  2014-07-10           lk    Sri Lanka
# 2661  800601468305081068  2014-10-09           sc   Seychelles
# 2901  681591497463996929  2017-05-12           yf       Serbia
# 3044  554641531246086557  2018-07-04           ro      Romania
#
#                          named_countries  \
# 2622          [Sri Lanka, United States]
# 2661  [India, Seychelles, United States]
# 2901             [Serbia, United States]
# 3044            [Romania, United States]
#
#                                            Project Name  \
# 2622  Disaster Risk Management Development Policy Lo...
# 2661  Disaster Risk Management Development Policy Lo...
# 2901  Disaster Risk Management Development Policy Lo...
# 3044  Disaster Risk Management Development Policy Lo...
#
#                                            project_desc  amount_standard  \
# 2622  SCHEDULE 2\n\nThe following table sets forth t...      102000000.0
# 2661  SCHEDULE 2\n\nAmortization Schedule\n\nSubject...        7000000.0
# 2901  SCHEDULE 2\n\nAmortization Schedule\n\nThe fol...       66100000.0
# 3044                                               None      400000000.0
#
#      currency_standard closing_month closing_day closing_year  \
# 2622         us dollar           May          31         2017
# 2661         us dollar     September          30         2017
# 2901              euro       October          31         2020
# 3044              euro      December          31         2021
#
#       loan_length in year wb_project_id
# 2622                  3.0       P166303
# 2661                  3.0       P166303
# 2901                  3.0       P166303
# 3044                  3.0       P166303

# %%
loan_features.loc[loan_features['wb_project_id'] =='P105002']
# Out:
#                       id        date country_code country_name  \
# 2002  586731468267593603  2008-06-06           id    Indonesia
# 2195  923601468041066358  2010-04-09           id    Indonesia
# 2354  926481468035093400  2011-07-27           id    Indonesia
#
#                  named_countries  \
# 2002  [Indonesia, United States]
# 2195  [Indonesia, United States]
# 2354  [Indonesia, United States]
#
#                                            Project Name  \
# 2002  National Program for Community Empowerment in ...
# 2195  Third National Program for Community Empowerme...
# 2354  Fourth National Program for Community  \nEmpow...
#
#                                            project_desc  amount_standard  \
# 2002                                               None       41190000.0
# 2195  SCHEDULE 1 \n\nProject Description \n\nThe obj...      785000000.0
# 2354  SCHEDULE 1 \n\nProject Description \n\nThe obj...      531190000.0
#
#      currency_standard closing_month closing_day closing_year  \
# 2002         us dollar
# 2195         us dollar      December          31         2012
# 2354         us dollar          June          30         2014
#
#       loan_length in year wb_project_id
# 2002                  NaN       P105002
# 2195                  2.0       P105002
# 2354                  3.0       P105002

# %%
loan_features.loc[loan_features['wb_project_id'] == 'P115566']
# Out:
#                       id        date country_code country_name  \
# 1983  293771468033359914  2008-03-28           in        India
# 2172  252861468252300804  2009-10-13           in        India
#
#              named_countries                             Project Name  \
# 1983  [India, United States]  Fourth Power System Development Project
# 2172  [India, United States]   Fifth Power System Development Project
#
#                                            project_desc  amount_standard  \
# 1983  SCHEDULE 1 \n\nProject Description \n\nThe obj...     6.000000e+08
# 2172  SCHEDULE 1 \n\nProject Description \n\nThe obj...     1.000000e+09
#
#      currency_standard closing_month closing_day closing_year  \
# 1983         us dollar          July          31         2013
# 2172         us dollar          June          30         2015
#
#       loan_length in year wb_project_id
# 1983                  5.0       P115566
# 2172                  6.0       P115566

# %%
world_bank_projects.loc['P115566']
# Out:
# id                                                                    P115566
# regionname                                                         South Asia
# countryname                                               [Republic of India]
# lendinginstr                                     Investment Project Financing
# projectstatusdisplay                                                   Closed
# status                                                                 Closed
# project_name                           Fifth Power System Development Project
# boardapprovaldate                                   2009-09-22 00:00:00+00:00
# ibrdcommamt                                                      1000000000.0
# idacommamt                                                                  0
# totalamt                                                        1,000,000,000
# grantamt                                                                    0
# countryshortname                                                        India
# projectfinancialtype                                            [IBRD, Other]
# pdo                         The project development objective is to streng...
# esrc_ovrl_risk_rate                                                       NaN
# borrower                              Power Grid Corporation of India Limited
# impagency                             Power Grid Corporation of India Limited
# proj_last_upd_date                                       2020-08-14T00:00:00Z
# sector1                     {'Name': 'Energy Transmission and Distribution...
# theme1                      {'Name': 'Infrastructure services for private ...
# url                         https://projects.worldbank.org/en/projects-ope...
# totalcommamt                                                    1,000,000,000
# cons_serv_reqd_ind                                                        NaN
# closingdate                                              2019-05-31T00:00:00Z
# envassesmentcategorycode                                                    A
# sector2                                                                   NaN
# sector3                                                                   NaN
# project_abstract            {'cdata': 'The objective of the Fifth Power Sy...
# theme2                                                                    NaN
# sector1_name                             Energy Transmission and Distribution
# sector1_pct                                                               100
# sector2_name                                                              NaN
# sector2_pct                                                               NaN
# sector3_name                                                              NaN
# sector3_pct                                                               NaN
# major_sector_name                                      Energy and Extractives
# Name: P115566, dtype: object

# %%
loan_features.loc[loan_features['wb_project_id'] == 'P149528']
# Out:
#                       id        date country_code country_name  \
# 2927  171461502376530613  2017-07-07           cn        China
#
#              named_countries  \
# 2927  [China, United States]
#
#                                            Project Name  \
# 2927  Second Gansu Cultural and Natural Heritage Pro...
#
#                                            project_desc  amount_standard  \
# 2927  SCHEDULE 1\n\nProject Description\n\nThe objec...              NaN
#
#      currency_standard closing_month closing_day closing_year  \
# 2927                        December          31         2022
#
#       loan_length in year wb_project_id
# 2927                  5.0       P149528

# %%
world_bank_projects.loc['P149528']
# Out:
# id                                                                    P149528
# regionname                                              East Asia and Pacific
# countryname                                      [People's Republic of China]
# lendinginstr                                     Investment Project Financing
# projectstatusdisplay                                                   Active
# status                                                                 Active
# project_name                CH-Second Gansu Cultural and Natural Heritage ...
# boardapprovaldate                                   2017-02-24 00:00:00+00:00
# ibrdcommamt                                                       100000000.0
# idacommamt                                                                  0
# totalamt                                                          100,000,000
# grantamt                                                                    0
# countryshortname                                                        China
# projectfinancialtype                                            [IBRD, Other]
# pdo                         To conserve cultural and natural heritage, enh...
# esrc_ovrl_risk_rate                                                       NaN
# borrower                                           People's Republic of China
# impagency                          Gansu Culture Tourism Group, Co. Ltd (CTG)
# proj_last_upd_date                                       2021-01-08T00:00:00Z
# sector1                     {'Name': 'Public Administration - Industry, Tr...
# theme1                      {'Name': 'Other urban development', 'Percent':...
# url                         https://projects.worldbank.org/en/projects-ope...
# totalcommamt                                                      100,000,000
# cons_serv_reqd_ind                                                        NaN
# closingdate                                              2023-12-31T00:00:00Z
# envassesmentcategorycode                                                    A
# sector2                                    {'Name': 'Tourism', 'Percent': 74}
# sector3                          {'Name': 'Social Protection', 'Percent': 18}
# project_abstract            {'cdata': 'The development objective of the Se...
# theme2                                                                    NaN
# sector1_name                Public Administration - Industry, Trade and Se...
# sector1_pct                                                                 8
# sector2_name                                                          Tourism
# sector2_pct                                                              74.0
# sector3_name                                                Social Protection
# sector3_pct                                                              18.0
# major_sector_name                                 Industry and Trade/Services
# Name: P149528, dtype: object

# %% [markdown]
# They mostly look like the same project with "Second" or "Third" put on.

# %%
loan_features = loan_features.merge(world_bank_projects[['id','major_sector_name','sector1_name','sector2_name','sector3_name']], left_on='wb_project_id',right_on='id',how='left')

# %%
loan_features.rename({'id_x': 'id'}, axis=1,inplace=True)
loan_features.drop('id_y',axis=1,inplace=True)

# %%
loan_features.columns
# Out:
# Index(['id', 'date', 'country_code', 'country_name', 'named_countries',
#        'Project Name', 'project_desc', 'amount_standard', 'currency_standard',
#        'closing_month', 'closing_day', 'closing_year', 'loan_length in year',
#        'wb_project_id', 'major_sector_name', 'sector1_name', 'sector2_name',
#        'sector3_name'],
#       dtype='object')

# %%
loan_features.to_pickle('agreement_features_join_projects.pkl')

# %%
world_bank_projects.columns
# Out:
# Index(['id', 'regionname', 'countryname', 'lendinginstr',
#        'projectstatusdisplay', 'status', 'project_name', 'boardapprovaldate',
#        'ibrdcommamt', 'idacommamt', 'totalamt', 'grantamt', 'countryshortname',
#        'projectfinancialtype', 'pdo', 'esrc_ovrl_risk_rate', 'borrower',
#        'impagency', 'proj_last_upd_date', 'sector1', 'theme1', 'url',
#        'totalcommamt', 'cons_serv_reqd_ind', 'closingdate',
#        'envassesmentcategorycode', 'sector2', 'sector3', 'project_abstract',
#        'theme2', 'sector1_name', 'sector1_pct', 'sector2_name', 'sector2_pct',
#        'sector3_name', 'sector3_pct', 'major_sector_name'],
#       dtype='object')

# %%
loan_features.dropna(how='any',inplace=False,subset=['project_desc','Project Name','major_sector_name']).describe()
# Out:
#                  id  amount_standard  loan_length in year
# count  9.070000e+02     7.740000e+02           893.000000
# mean   5.337426e+17     1.862315e+08             2.403135
# std    2.548703e+17     6.985554e+08            60.910642
# min    1.016115e+17     2.000000e+05         -1815.000000
# 25%    3.182015e+17     3.000000e+07             4.000000
# 50%    5.163015e+17     8.400000e+07             5.000000
# 75%    7.490465e+17     1.800000e+08             6.000000
# max    9.995615e+17     1.178000e+10             9.000000
